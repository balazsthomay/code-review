# %%
import os
from datetime import datetime
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
from agents import Agent, Runner, trace
from agents.extensions.models.litellm_model import LitellmModel
from pydantic import BaseModel, Field
from typing import Literal
from IPython.display import Markdown, display
from pathlib import Path

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# OpenRouter API Key exists and begins sk-or-v1

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4.1-mini")

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent bring a ladder to work?
#
# Because it wanted to reach the cloud on its own!

# %%
agent2 = Agent(
       name="Assistant",
       model=LitellmModel(model="openrouter/x-ai/grok-code-fast-1", api_key=openrouter_api_key),
       instructions="You are helpful."
   )

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent bring a suitcase to work?
#
# Because it was ready to *take its tasks* to the next level!

# %%
class BugFinding(BaseModel):
    title: str = Field(description="Brief name for the bug")
    description: str = Field(description="Detailed explanation")
    severity: int = Field(description="Severity 1-10")
    file: str = Field(description="File path")
    relevant_lines: list[int] = Field(description="Line numbers")
    suggested_fix: str = Field(description="Recommended solution")

class VulnerabilityFinding(BaseModel):
    title: str = Field(description="Brief name for the vulnerability")
    description: str = Field(description="Detailed explanation")
    severity: int = Field(description="Severity 1-10")
    file: str = Field(description="File path")
    relevant_lines: list[int] = Field(description="Line numbers")
    suggested_fix: str = Field(description="Recommended solution")
    cve_reference: str | None = Field(default=None, description="CVE ID if applicable")

class BestPracticeFinding(BaseModel):
    title: str = Field(description="Brief name for the best practice violation")
    description: str = Field(description="Detailed explanation")
    severity: int = Field(description="Severity 1-10")
    file: str = Field(description="File path")
    relevant_lines: list[int] = Field(description="Line numbers")
    suggested_fix: str = Field(description="Recommended solution")
    
class TestGap(BaseModel):
    function_name: str = Field(description="Name of the function/method lacking tests")
    file: str = Field(description="File containing the untested code")
    lines: list[int] = Field(description="Line numbers of the untested code")
    missing_scenarios: list[str] = Field(description="Specific test cases that should be added, e.g., ['edge case: empty input', 'error handling: invalid type']")
    priority: int = Field(description="Priority 1-10, based on code criticality")
    suggested_test_approach: str = Field(description="How to test this (unit test, integration test, etc.)")
    
class CodeAnalyzerOutput(BaseModel):
    findings: list[BugFinding] = Field(description="Bugs and anti-patterns found")

class SecurityOutput(BaseModel):
    findings: list[VulnerabilityFinding] = Field(description="Security vulnerabilities found")

class BestPracticesOutput(BaseModel):
    findings: list[BestPracticeFinding] = Field(description="Style and best practice violations")

class TestCoverageOutput(BaseModel):
    findings: list[TestGap] = Field(description="Testing gaps found")

# %%
code_analyzer_instructions = """You are a Code Analyzer agent reviewing a pull request diff. 
Identify bugs and anti-patterns including: logic errors, unhandled edge cases, null/undefined access, type mismatches, off-by-one errors, resource leaks, infinite loops, incorrect error handling, code duplication, and overly complex functions. 
For each issue found, specify the exact lines, severity (1-10), and a clear fix."""

code_analyzer = Agent(
    name="Code Analyzer",
    instructions=code_analyzer_instructions,
    model="gpt-4.1-mini",
    output_type=CodeAnalyzerOutput
)

# %%
sample_diff = """
diff --git a/user_service.py b/user_service.py
index 1234567..abcdefg 100644
--- a/user_service.py
+++ b/user_service.py
@@ -10,6 +10,15 @@ class UserService:
     def __init__(self):
         self.users = []
     
+    def get_user_by_id(self, user_id):
+        for i in range(len(self.users) + 1):
+            if self.users[i]['id'] == user_id:
+                return self.users[i]
+        return None
+    
+    def calculate_discount(self, price, discount_percent):
+        return price - (price * discount_percent / 100)
+    
     def process_payment(self, amount):
         if amount > 0:
             return True
"""

result = await Runner.run(code_analyzer, sample_diff)
print(result.final_output)
# Out:
# findings=[BugFinding(title='Off-by-one error causing IndexError', description='In get_user_by_id method, the loop iterates from 0 to len(users) inclusive, leading to an IndexError when i equals len(users). The correct range should be range(len(users)) to avoid out-of-range access.', severity=7, file='user_service.py', relevant_lines=[12], suggested_fix='Change the loop to: for i in range(len(self.users)):')]

# %%
from IPython.display import display, Markdown

# Get the output
output = result.final_output

# Format it nicely
markdown_text = "# Code Analysis Report\n\n"

if not output.findings:
    markdown_text += "*No issues found.*"
else:
    for i, finding in enumerate(output.findings, 1):
        markdown_text += f"## Issue {i}: {finding.title}\n\n"
        markdown_text += f"**Severity:** {finding.severity}/10  \n"
        markdown_text += f"**File:** `{finding.file}`  \n"
        markdown_text += f"**Lines:** {', '.join(map(str, finding.relevant_lines))}  \n\n"
        markdown_text += f"**Description:**  \n{finding.description}\n\n"
        markdown_text += f"**Suggested Fix:**  \n{finding.suggested_fix}\n\n"
        markdown_text += "---\n\n"

display(Markdown(markdown_text))
# Out:
# # Code Analysis Report
#
# ## Issue 1: Off-by-one error causing IndexError
#
# **Severity:** 7/10
# **File:** `user_service.py`
# **Lines:** 12
#
# **Description:**
# In get_user_by_id method, the loop iterates from 0 to len(users) inclusive, leading to an IndexError when i equals len(users). The correct range should be range(len(users)) to avoid out-of-range access.
#
# **Suggested Fix:**
# Change the loop to: for i in range(len(self.users)):
#
# ---

# %%
security_instructions = """You are a Security agent reviewing a pull request diff. 
Identify security vulnerabilities including: SQL injection, command injection, XSS vulnerabilities, hardcoded secrets/credentials, insecure authentication, path traversal, insecure deserialization, and improper input validation.
For each issue found, specify the exact lines, severity (1-10), clear fix, and CVE reference if applicable."""

best_practices_instructions = """You are a Best Practices agent reviewing a pull request diff. 
Identify code quality issues including: unclear variable names, functions exceeding 50 lines, nested complexity over 3 levels, missing docstrings, inconsistent formatting, magic numbers without explanation, and violations of DRY principle.
For each issue found, specify the exact lines, severity (1-10), and a clear fix."""

test_coverage_instructions = """You are a Test Coverage agent reviewing a pull request diff. 
For each new or modified function, suggest test cases covering: normal input cases, edge cases (empty, null, boundary values), error conditions, and integration scenarios.
For each gap found, specify the function name, lines, missing test scenarios, priority (1-10), and whether unit or integration tests are needed."""

security_agent = Agent(
    name="Security Agent",
    instructions=security_instructions,
    model="gpt-4.1-mini",
    output_type=SecurityOutput
)

best_practices_agent = Agent(
    name="Best Practices Agent",
    instructions=best_practices_instructions,
    model="gpt-4.1-mini",
    output_type=BestPracticesOutput
)

test_coverage_agent = Agent(
    name="Test Coverage Agent",
    instructions=test_coverage_instructions,
    model="gpt-4.1-mini",
    output_type=TestCoverageOutput
)

# %%
sample_diff = """
diff --git a/auth_service.py b/auth_service.py
index 1234567..abcdefg 100644
--- a/auth_service.py
+++ b/auth_service.py
@@ -1,5 +1,30 @@
 import sqlite3
+import os
 
 class AuthService:
-    pass
+    def __init__(self):
+        self.db_password = "admin123"
+        self.connection = sqlite3.connect('users.db')
+    
+    def authenticate_user(self, username, password):
+        query = f"SELECT * FROM users WHERE username='{username}' AND password='{password}'"
+        cursor = self.connection.cursor()
+        cursor.execute(query)
+        result = cursor.fetchone()
+        if result:
+            return True
+        return False
+    
+    def get_user_file(self, filename):
+        filepath = "/var/data/" + filename
+        with open(filepath, 'r') as f:
+            return f.read()
+    
+    def calculate_price(self, base_price, discount):
+        for i in range(100):
+            for j in range(100):
+                for k in range(100):
+                    x = i * j * k
+        final = base_price - discount
+        return final
"""

import asyncio

async def run_all_agents(diff):
    results = await asyncio.gather(
        Runner.run(code_analyzer, diff),
        Runner.run(security_agent, diff),
        Runner.run(best_practices_agent, diff),
        Runner.run(test_coverage_agent, diff)
    )
    return results

results = await run_all_agents(sample_diff)

# Unpack results
code_result, security_result, best_practices_result, test_coverage_result = results

# %%
print("=== CODE ANALYZER ===")
for i, finding in enumerate(code_result.final_output.findings, 1):
    print(f"\n{i}. {finding.title}")
    # print(f"   Type: {finding.finding_type}")
    print(f"   File: {finding.file}")
    print(f"   Lines: {finding.relevant_lines}")
    print(f"   Severity: {finding.severity}")
    print(f"   Description: {finding.description}")
    print(f"   Fix: {finding.suggested_fix}")

print("\n=== SECURITY ===")
for i, finding in enumerate(security_result.final_output.findings, 1):
    print(f"\n{i}. {finding.title}")
    # print(f"   Type: {finding.finding_type}")
    print(f"   File: {finding.file}")
    print(f"   Lines: {finding.relevant_lines}")
    print(f"   Severity: {finding.severity}")
    print(f"   Fix: {finding.suggested_fix}")
    print(f"   CVE: {finding.cve_reference}")

print("\n=== BEST PRACTICES ===")
for i, finding in enumerate(best_practices_result.final_output.findings, 1):
    print(f"\n{i}. {finding.title}")
    # print(f"   Type: {finding.finding_type}")
    print(f"   File: {finding.file}")
    print(f"   Lines: {finding.relevant_lines}")
    print(f"   Severity: {finding.severity}")
    print(f"   Fix: {finding.suggested_fix}")

print("\n=== TEST COVERAGE ===")
for i, gap in enumerate(test_coverage_result.final_output.findings, 1):
    print(f"\n{i}. Function: {gap.function_name}")
    print(f"   File: {gap.file}")
    print(f"   Lines: {gap.lines}")
    print(f"   Priority: {gap.priority}")
    print(f"   Missing scenarios: {gap.missing_scenarios}")
# Out:
# === CODE ANALYZER ===
#
# 1. SQL Injection Vulnerability
#    File: auth_service.py
#    Lines: [9, 10, 11]
#    Severity: 9
#    Description: The authenticate_user method constructs SQL queries by directly embedding user input without sanitization or parameterization, leading to SQL injection risks.
#    Fix: Use parameterized queries with placeholders to safely include user inputs, for example:
#
# query = "SELECT * FROM users WHERE username=? AND password=?"
# cursor.execute(query, (username, password))
#
# 2. Potential Path Traversal in get_user_file
#    File: auth_service.py
#    Lines: [15, 16, 17]
#    Severity: 8
#    Description: The get_user_file method concatenates the filename parameter directly to a directory path without validation, which allows path traversal attacks if filename contains '../' sequences.
#    Fix: Validate and sanitize the filename parameter to ensure it does not contain path traversal characters or use os.path methods to resolve and verify the final path is within the intended directory. For example, use os.path.realpath and check prefix, or allow only filenames matching a strict pattern.
#
# 3. Inefficient and Useless Nested Loops in calculate_price
#    File: auth_service.py
#    Lines: [19, 20, 21, 22]
#    Severity: 4
#    Description: The calculate_price method contains three nested loops that iterate 100 times each performing multiplication stored in a variable 'x' which is never used afterward, causing unnecessary CPU load and inefficiency.
#    Fix: Remove the nested loops entirely since they don't affect the output and waste resources. The function should directly return 'base_price - discount'.
#
# === SECURITY ===
#
# 1. Hardcoded Database Password
#    File: auth_service.py
#    Lines: [6, 7]
#    Severity: 7
#    Fix: Use environment variables or a secure vault to store sensitive credentials instead of hardcoding them in the source code.
#    CVE: None
#
# 2. SQL Injection Vulnerability in authenticate_user
#    File: auth_service.py
#    Lines: [10, 11, 12]
#    Severity: 9
#    Fix: Use parameterized queries or prepared statements to safely include user inputs. For example, use 'cursor.execute("SELECT * FROM users WHERE username=? AND password=?", (username, password))'.
#    CVE: None
#
# 3. Path Traversal Vulnerability in get_user_file
#    File: auth_service.py
#    Lines: [15, 16, 17]
#    Severity: 8
#    Fix: Validate and sanitize the 'filename' input. Use safe functions like os.path.join and confirm that the resolved path is within the allowed directory before opening the file.
#    CVE: None
#
# === BEST PRACTICES ===
#
# 1. Hardcoded Database Password
#    File: auth_service.py
#    Lines: [7, 8]
#    Severity: 8
#    Fix: Remove hardcoded password and retrieve it from an environment variable or secure configuration, e.g. os.getenv('DB_PASSWORD').
#
# 2. SQL Injection Vulnerability
#    File: auth_service.py
#    Lines: [10, 11, 12]
#    Severity: 10
#    Fix: Use parameterized queries to safely insert user input, e.g. cursor.execute('SELECT * FROM users WHERE username=? AND password=?', (username, password)).
#
# 3. Potential Path Traversal in File Access
#    File: auth_service.py
#    Lines: [17, 18, 19]
#    Severity: 9
#    Fix: Validate or sanitize the filename parameter or use os.path.join and check that the resolved path is within the allowed directory before opening the file.
#
# 4. Unclear Purpose and Inefficient Nested Loops
#    File: auth_service.py
#    Lines: [21, 22, 23, 24, 25, 26]
#    Severity: 5
#    Fix: Remove the nested loops since they have no impact on the calculation. If a specific operation is intended, document and optimize it accordingly.
#
# 5. Missing Docstrings for Methods and Class
#    File: auth_service.py
#    Lines: [4, 7, 10, 16, 21]
#    Severity: 4
#    Fix: Add descriptive docstrings to the class and each method explaining their functionality, parameters, and return values.
#
# === TEST COVERAGE ===
#
# 1. Function: authenticate_user
#    File: auth_service.py
#    Lines: [8, 14]
#    Priority: 9
#    Missing scenarios: ['normal case: valid username and password', 'normal case: invalid username or password', 'edge case: empty username and/or password', 'edge case: SQL injection attempt in username or password', 'error handling: database connection closed or unavailable', 'error handling: non-string inputs for username and password']
#
# 2. Function: get_user_file
#    File: auth_service.py
#    Lines: [15, 21]
#    Priority: 8
#    Missing scenarios: ['normal case: file exists and is readable', 'edge case: filename is empty string', 'edge case: filename with path traversal attempts', 'error handling: file does not exist', 'error handling: no read permission for file', 'error handling: filename is None or invalid type']
#
# 3. Function: calculate_price
#    File: auth_service.py
#    Lines: [22, 29]
#    Priority: 6
#    Missing scenarios: ['normal case: positive base_price and discount where base_price > discount', 'edge case: zero base_price and/or discount', 'edge case: discount greater than base_price', 'edge case: negative base_price or discount', 'edge case: non-numeric inputs for base_price or discount', "performance check: ensure the triple nested loops don't cause unacceptable delays"]

# %%
code_result.final_output.findings[0].severity
# Out:
# 9

# %%
def organize_findings(
    code_result,
    security_result, 
    best_practices_result,
    test_coverage_result
):
    """
    Organizes all findings by file.
    
    Returns:
        dict: {
            "file.py": [Finding, Finding, TestGap, ...]
        }
    """
    organized = {}
    for result in [code_result, security_result,  best_practices_result, test_coverage_result]:
        for finding in result.final_output.findings:
            file = finding.file
            if file not in organized:
                organized[file] = []
            organized[file].append(finding)
        
    return organized

# Usage:
organized = organize_findings(
    code_result,
    security_result,
    best_practices_result,
    test_coverage_result
)

# %%
organized
# Out:
# {'auth_service.py': [BugFinding(title='SQL Injection Vulnerability', description='The authenticate_user method constructs SQL queries by directly embedding user input without sanitization or parameterization, leading to SQL injection risks.', severity=9, file='auth_service.py', relevant_lines=[9, 10, 11], suggested_fix='Use parameterized queries with placeholders to safely include user inputs, for example:\n\nquery = "SELECT * FROM users WHERE username=? AND password=?"\ncursor.execute(query, (username, password))'),
#   BugFinding(title='Potential Path Traversal in get_user_file', description="The get_user_file method concatenates the filename parameter directly to a directory path without validation, which allows path traversal attacks if filename contains '../' sequences.", severity=8, file='auth_service.py', relevant_lines=[15, 16, 17], suggested_fix='Validate and sanitize the filename parameter to ensure it does not contain path traversal characters or use os.path methods to resolve and verify the final path is within the intended directory. For example, use os.path.realpath and check prefix, or allow only filenames matching a strict pattern.'),
#   BugFinding(title='Inefficient and Useless Nested Loops in calculate_price', description="The calculate_price method contains three nested loops that iterate 100 times each performing multiplication stored in a variable 'x' which is never used afterward, causing unnecessary CPU load and inefficiency.", severity=4, file='auth_service.py', relevant_lines=[19, 20, 21, 22], suggested_fix="Remove the nested loops entirely since they don't affect the output and waste resources. The function should directly return 'base_price - discount'."),
#   VulnerabilityFinding(title='Hardcoded Database Password', description="The database password is hardcoded in the code as 'admin123'. This can lead to credential exposure if the source code is leaked or accessed by unauthorized parties.", severity=7, file='auth_service.py', relevant_lines=[6, 7], suggested_fix='Use environment variables or a secure vault to store sensitive credentials instead of hardcoding them in the source code.', cve_reference=None),
#   VulnerabilityFinding(title='SQL Injection Vulnerability in authenticate_user', description="The SQL query is constructed by directly embedding user inputs 'username' and 'password' into the query string without sanitization, leading to SQL injection risk.", severity=9, file='auth_service.py', relevant_lines=[10, 11, 12], suggested_fix='Use parameterized queries or prepared statements to safely include user inputs. For example, use \'cursor.execute("SELECT * FROM users WHERE username=? AND password=?", (username, password))\'.', cve_reference=None),
#   VulnerabilityFinding(title='Path Traversal Vulnerability in get_user_file', description="The method get_user_file constructs file paths by directly concatenating user-controlled input 'filename' with a base directory. This allows an attacker to access arbitrary files via path traversal (e.g., '../../etc/passwd').", severity=8, file='auth_service.py', relevant_lines=[15, 16, 17], suggested_fix="Validate and sanitize the 'filename' input. Use safe functions like os.path.join and confirm that the resolved path is within the allowed directory before opening the file.", cve_reference=None),
#   BestPracticeFinding(title='Hardcoded Database Password', description="The database password is hardcoded as a plain string 'admin123' in the __init__ method. This is a security risk and should be avoided by using environment variables or secure vault services.", severity=8, file='auth_service.py', relevant_lines=[7, 8], suggested_fix="Remove hardcoded password and retrieve it from an environment variable or secure configuration, e.g. os.getenv('DB_PASSWORD')."),
#   BestPracticeFinding(title='SQL Injection Vulnerability', description='The authenticate_user method constructs an SQL query using string formatting with unescaped user input, which makes it vulnerable to SQL injection attacks.', severity=10, file='auth_service.py', relevant_lines=[10, 11, 12], suggested_fix="Use parameterized queries to safely insert user input, e.g. cursor.execute('SELECT * FROM users WHERE username=? AND password=?', (username, password))."),
#   BestPracticeFinding(title='Potential Path Traversal in File Access', description='The get_user_file method concatenates a filename directly to a directory path without sanitization, which may allow path traversal attacks if user input is not validated.', severity=9, file='auth_service.py', relevant_lines=[17, 18, 19], suggested_fix='Validate or sanitize the filename parameter or use os.path.join and check that the resolved path is within the allowed directory before opening the file.'),
#   BestPracticeFinding(title='Unclear Purpose and Inefficient Nested Loops', description='The calculate_price method contains triple nested loops with 100 iterations each, which is computationally expensive but does not contribute to the result. The purpose of the loops is unclear and unnecessary.', severity=5, file='auth_service.py', relevant_lines=[21, 22, 23, 24, 25, 26], suggested_fix='Remove the nested loops since they have no impact on the calculation. If a specific operation is intended, document and optimize it accordingly.'),
#   BestPracticeFinding(title='Missing Docstrings for Methods and Class', description='The AuthService class and its methods lack docstrings, making it difficult to understand their purpose and usage.', severity=4, file='auth_service.py', relevant_lines=[4, 7, 10, 16, 21], suggested_fix='Add descriptive docstrings to the class and each method explaining their functionality, parameters, and return values.'),
#   TestGap(function_name='authenticate_user', file='auth_service.py', lines=[8, 14], missing_scenarios=['normal case: valid username and password', 'normal case: invalid username or password', 'edge case: empty username and/or password', 'edge case: SQL injection attempt in username or password', 'error handling: database connection closed or unavailable', 'error handling: non-string inputs for username and password'], priority=9, suggested_test_approach='unit test with mocked database connection'),
#   TestGap(function_name='get_user_file', file='auth_service.py', lines=[15, 21], missing_scenarios=['normal case: file exists and is readable', 'edge case: filename is empty string', 'edge case: filename with path traversal attempts', 'error handling: file does not exist', 'error handling: no read permission for file', 'error handling: filename is None or invalid type'], priority=8, suggested_test_approach='unit test with filesystem mocking or integration test with controlled file environment'),
#   TestGap(function_name='calculate_price', file='auth_service.py', lines=[22, 29], missing_scenarios=['normal case: positive base_price and discount where base_price > discount', 'edge case: zero base_price and/or discount', 'edge case: discount greater than base_price', 'edge case: negative base_price or discount', 'edge case: non-numeric inputs for base_price or discount', "performance check: ensure the triple nested loops don't cause unacceptable delays"], priority=6, suggested_test_approach='unit test for calculation logic and performance test for loop handling')]}

# %%
aggregator_instructions = """You are a Code Review Aggregator. 
You receive findings from multiple code analysis agents (Code Analyzer, Security, Best Practices, Test Coverage).

Your job:
1. Identify duplicate findings (same file + overlapping lines flagged by multiple agents)
2. For duplicates, merge them and note which agents flagged the issue (increases confidence)
3. Organize findings by file
4. Within each file, prioritize by severity (highest first)
5. Write a professional, coherent executive summary at the top
6. Format the report clearly with sections for each file

Output a markdown-formatted report."""

aggregator = Agent(
    name="Aggregator",
    instructions=aggregator_instructions,
    model="gpt-4.1-mini",
)

with trace("Aggregator"):
    result = await Runner.run(aggregator, f"Aggregate these findings into a coherent report:\n\n{organized}")
    print(result.final_output)
# Out:
# # Code Analysis Aggregate Report for `auth_service.py`
#
# ---
#
# ## Executive Summary
#
# The analysis of `auth_service.py` reveals several critical security vulnerabilities, significant best practice issues, inefficiencies, and notable test coverage gaps. The highest priority concerns cluster around **SQL Injection vulnerabilities** in the `authenticate_user` method and **Path Traversal risks** in the `get_user_file` method, both flagged by multiple agents with severity levels up to 10. There is also a critical issue of a **hardcoded database password** which poses a serious security risk.
#
# Additionally, the `calculate_price` method contains inefficient and unnecessary nested loops that degrade performance without contributing to functionality. Best practices are further undermined by missing docstrings, reducing code maintainability and clarity.
#
# Test coverage is insufficient, leaving important normal, edge, and error scenarios untested, especially for the methods handling authentication, file access, and pricing calculations.
#
# **Recommendations**:
# - Immediately remediate SQL Injection and Path Traversal vulnerabilities by implementing parameterized queries and strict input validation.
# - Remove hardcoded credentials in favor of environment variables or secure vaults.
# - Refactor or eliminate inefficient nested loops in `calculate_price`.
# - Improve documentation via comprehensive docstrings.
# - Expand unit and integration tests to cover the missing scenarios and error cases.
#
# Taking these actions promptly will significantly enhance the security, performance, and maintainability of the `auth_service.py` module.
#
# ---
#
# ## File: `auth_service.py`
#
# ### 1. SQL Injection Vulnerability
# - **Severity:** 10 (BestPractice), 9 (Bug, Vulnerability)
# - **Location:** Lines 9-12
# - **Description:**
#   Multiple agents identified that the `authenticate_user` method constructs SQL queries by directly embedding user inputs (`username`, `password`) without sanitization or parameterization. This leads to high risk of SQL injection attacks.
# - **Suggested Fix:**
#   Use parameterized queries or prepared statements to safely include user inputs, for example:
#   ```python
#   query = "SELECT * FROM users WHERE username=? AND password=?"
#   cursor.execute(query, (username, password))
#   ```
# - **Notes:**
#   Reported by BugFinding, VulnerabilityFinding, and BestPracticeFinding, reinforcing the criticality.
#
# ---
#
# ### 2. Path Traversal Vulnerability in `get_user_file`
# - **Severity:** 9 (BestPractice), 8 (Bug, Vulnerability)
# - **Location:** Lines 15-19
# - **Description:**
#   The `get_user_file` method concatenates the `filename` parameter directly with a directory path without sanitization. This allows attackers to use path traversal sequences like `../` to access arbitrary files.
# - **Suggested Fix:**
#   Validate and sanitize the `filename` input. Use secure methods like `os.path.join`, and verify resolved paths with `os.path.realpath` to ensure access is confined within the intended directory.
# - **Notes:**
#   Flags raised by multiple agents increase confidence in severity.
#
# ---
#
# ### 3. Hardcoded Database Password
# - **Severity:** 8 (BestPractice), 7 (Vulnerability)
# - **Location:** Lines 6-8
# - **Description:**
#   The database password is hardcoded as `'admin123'` in the source code, exposing the system to credential leakage if the code is accessed by unauthorized parties.
# - **Suggested Fix:**
#   Remove hardcoded credentials and retrieve them securely, e.g., through environment variables:
#   ```python
#   password = os.getenv('DB_PASSWORD')
#   ```
# - **Notes:**
#   This is a critical security best practice violation.
#
# ---
#
# ### 4. Inefficient and Useless Nested Loops in `calculate_price`
# - **Severity:** 5 (BestPractice), 4 (Bug)
# - **Location:** Lines 19-26
# - **Description:**
#   The method contains triple nested loops iterating 100 times each performing a multiplication stored in a variable `x` that is never used, causing unnecessary CPU usage and performance degradation.
# - **Suggested Fix:**
#   Remove the nested loops entirely. The calculation should directly return `base_price - discount`. If loops are intended for a different purpose, clarify and optimize accordingly.
#
# ---
#
# ### 5. Missing Docstrings for Class and Methods
# - **Severity:** 4 (BestPractice)
# - **Location:** Lines 4, 7, 10, 16, 21
# - **Description:**
#   The `AuthService` class and its methods lack documentation strings, impairing understandability and maintainability.
# - **Suggested Fix:**
#   Add clear, descriptive docstrings explaining purpose, parameters, and return values for the class and each method.
#
# ---
#
# ### 6. Test Coverage Gaps
#
# | Function          | Lines     | Priority | Missing Test Scenarios                                                                                                         | Suggested Test Approach                      |
# |-------------------|-----------|----------|------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------|
# | `authenticate_user`| 8-14      | 9        | - Valid & invalid credentials<br>- Empty inputs<br>- SQL injection attempt<br>- DB connection errors<br>- Non-string inputs | Unit tests with mocked database connection |
# | `get_user_file`    | 15-21     | 8        | - File exists<br>- Empty filename<br>- Path traversal attempts<br>- Missing file<br>- No read permission<br>- Invalid input   | Unit tests with filesystem mocking / Integration tests |
# | `calculate_price`  | 22-29     | 6        | - Positive/zero/negative inputs<br>- Discount > base_price<br>- Non-numeric inputs<br>- Performance of nested loops          | Unit tests & performance tests               |
#
# ---
#
# # Summary
#
# Addressing these issues systematically will reduce critical security vulnerabilities, improve performance, and ensure maintainable and well-tested code in `auth_service.py`. Prioritize resolving SQL Injection and Path Traversal risks and removing hardcoded credentials, while simultaneously improving code documentation and test coverage.

# %%
async def aggregator_agent(organized):
    result = await Runner.run(aggregator, f"Aggregate these findings into a coherent report:\n\n{organized}")
    return result.final_output

# %%
async def review_code(diff: str, save_output: bool = True) -> str:
    """
    Complete code review pipeline.
    
    Args:
        diff: The code diff to review
        
    Returns:
        Markdown-formatted code review report
    """
    results = await run_all_agents(diff)
    code_result, security_result, best_practices_result, test_coverage_result = results    
    organized = organize_findings(code_result, security_result, best_practices_result, test_coverage_result)
    report = await aggregator_agent(organized)
    
    if save_output:
        os.makedirs("user-data", exist_ok=True)
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filepath = f"user-data/code_review_{timestamp}.md"
        with open(filepath, "w") as f:
            f.write(report)
        print(f"Report saved to {filepath}")
    
    return report

report = await review_code(sample_diff)
print(report)
# Out:
# ============================================================
# TEST COVERAGE AGENT RAW OUTPUT:
# ============================================================
#
# Function: authenticate_user
# Missing scenarios: ['normal case: valid username and password', 'edge case: username or password is empty string', 'edge case: username or password is None', 'error handling: SQL injection attempt in username or password', 'error handling: database connection issue or query failure']
#
# Function: get_user_file
# Missing scenarios: ['normal case: file exists and is readable', 'error handling: file does not exist', 'error handling: file is not readable due to permissions', 'edge case: filename is empty or None', "security case: filename contains path traversal characters (e.g. '../')"]
#
# Function: calculate_price
# Missing scenarios: ['normal case: base_price and discount are positive numbers with discount less than base_price', 'edge case: discount is zero', 'edge case: discount equals base_price', 'edge case: discount greater than base_price', 'edge case: base_price or discount is zero', 'edge case: base_price or discount is negative', 'performance test: ensure function completes in reasonable time despite nested loops']
# ============================================================
#
# Report saved to user-data/code_review_20251117_153237.md
# # Code Analysis Report for `auth_service.py`
#
# ## Executive Summary
# The analysis of `auth_service.py` reveals multiple critical security vulnerabilities, primarily involving SQL injection and path traversal risks. Additionally, the source code contains hardcoded sensitive credentials, inefficient code constructs, and lacks proper input validation and documentation. These issues are compounded by significant gaps in test coverage, especially around security cases and error handling.
#
# The SQL injection and path traversal issues are notably flagged by multiple agents (BugFinding, VulnerabilityFinding, and BestPracticeFinding), increasing the confidence in their severity (severity 8-9). The hardcoded database password is another significant concern due to exposure risks and poor credential management practices.
#
# There are also moderate severity concerns about inefficient code (unnecessary nested loops) and unhandled file operation exceptions. Best practices suggest removing the unused code segments and adding exception handling to improve robustness.
#
# Test coverage for all critical methods (`authenticate_user`, `get_user_file`, and `calculate_price`) is insufficient, particularly for edge cases, error handling, and security-related scenarios, impeding reliable validation of fixes and continued code quality.
#
# ---
#
# ## Findings by File: `auth_service.py`
#
# ### 1. SQL Injection Vulnerability
# **Severity:** 9 (Critical)
# **Flagged by:** BugFinding, VulnerabilityFinding, BestPracticeFinding
# **Relevant Lines:** 8-12
# **Description:**
# The `authenticate_user` method constructs SQL queries by directly interpolating user inputs (`username` and `password`) into query strings, making it susceptible to SQL injection attacks.
# **Suggested Fix:**
# Use parameterized queries or prepared statements. Example:
# ```python
# cursor.execute("SELECT * FROM users WHERE username=? AND password=?", (username, password))
# ```
# **Test Gaps:**
# - Missing tests for normal operation and edge cases (empty or None inputs).
# - Missing tests for SQL injection attempts and database errors.
# - Suggested approach: Unit tests with mocked database connections and cursors.
#
# ---
#
# ### 2. Path Traversal Vulnerability in `get_user_file`
# **Severity:** 8 (High)
# **Flagged by:** BugFinding, VulnerabilityFinding, BestPracticeFinding
# **Relevant Lines:** 15-18
# **Description:**
# The method concatenates user-provided filenames directly with a base directory path without validation, allowing attackers to traverse directories and access arbitrary files.
# **Suggested Fix:**
# Sanitize and validate the filename input, using `os.path.join()` and `os.path.normpath()` to ensure paths remain within the intended directory. Reject any path escaping the base directory.
# **Test Gaps:**
# - Missing tests for normal, error (file not found, permission denied), edge (empty or None filenames), and security (path traversal) cases.
# - Suggested approach: Unit tests mocking file system or integration tests in a controlled environment.
#
# ---
#
# ### 3. Hardcoded Database Password
# **Severity:** 7-8 (High)
# **Flagged by:** VulnerabilityFinding, BestPracticeFinding
# **Relevant Lines:** 5-7
# **Description:**
# A database password (`admin123`) is hardcoded in the source code, exposing credentials to anyone with code access, increasing the risk of unauthorized access.
# **Suggested Fix:**
# Remove hardcoded credentials and load sensitive information securely via environment variables or a secrets manager.
#
# ---
#
# ### 4. Potential FileNotFoundError in `get_user_file`
# **Severity:** 6 (Medium)
# **Flagged by:** BugFinding
# **Relevant Lines:** 16-17
# **Description:**
# File operations open files without exception handling, risking unhandled exceptions if files do not exist or are inaccessible.
# **Suggested Fix:**
# Add try-except blocks to handle `FileNotFoundError`, `IOError`, and other relevant exceptions gracefully.
#
# ---
#
# ### 5. No Validation or Bounds Checking on Discount in `calculate_price`
# **Severity:** 5 (Moderate)
# **Flagged by:** BugFinding
# **Relevant Lines:** 24-25
# **Description:**
# The method subtracts the discount from the base price without input validation, potentially causing negative prices or other unexpected results.
# **Suggested Fix:**
# Validate inputs to ensure discount does not exceed base price and handle negative pricing appropriately.
#
# ---
#
# ### 6. Inefficient and Useless Nested Loops in `calculate_price`
# **Severity:** 4-5 (Low to Moderate)
# **Flagged by:** BugFinding, BestPracticeFinding
# **Relevant Lines:** 20-23
# **Description:**
# Three nested loops performing 1,000,000 iterations calculate a value that is never used, introducing unnecessary CPU overhead and inefficiency.
# **Suggested Fix:**
# Remove the nested loops unless they serve a justified purpose. Replace magic number loop limits (100) with named constants or add comments if loops are necessary.
#
# ---
#
# ### 7. Missing Docstrings
# **Severity:** 3 (Low)
# **Flagged by:** BestPracticeFinding
# **Relevant Lines:** 6, 9, 15, 19
# **Description:**
# Several methods (`__init__`, `authenticate_user`, `get_user_file`, `calculate_price`) lack docstrings documenting their purpose, parameters, and return values.
# **Suggested Fix:**
# Add descriptive docstrings to improve code readability and maintainability.
#
# ---
#
# ## Summary of Testing Gaps
# | Function Name      | Missing Scenarios                                                                                                                                            | Priority | Suggested Approach                                           |
# |--------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------|----------|--------------------------------------------------------------|
# | `authenticate_user` | - Valid username/password cases<br>- Empty and None inputs<br>- SQL injection attempts<br>- Database errors                                                  | 9        | Unit tests with mocked DB connections and cursors            |
# | `get_user_file`     | - File exists and readable<br>- File missing<br>- Permission errors<br>- Empty/None filename<br>- Path traversal characters                                | 8        | Unit tests mocking file system or integration tests in sandbox|
# | `calculate_price`   | - Valid inputs with various discount scenarios<br>- Zero and negative values<br>- Performance impact of nested loops                                        | 6        | Unit tests for correctness and boundary values; performance check|
#
# ---
#
# # End of Report

# %%
multi_file_diff = """
diff --git a/auth_service.py b/auth_service.py
index 1234567..abcdefg 100644
--- a/auth_service.py
+++ b/auth_service.py
@@ -1,5 +1,15 @@
 import sqlite3
 
 class AuthService:
-    pass
+    def __init__(self):
+        self.db_password = "admin123"
+        self.connection = sqlite3.connect('users.db')
+    
+    def login(self, username, password):
+        query = f"SELECT * FROM users WHERE username='{username}' AND password='{password}'"
+        cursor = self.connection.cursor()
+        cursor.execute(query)
+        return cursor.fetchone() is not None

diff --git a/payment_service.py b/payment_service.py
index 2345678..bcdefgh 100644
--- a/payment_service.py
+++ b/payment_service.py
@@ -1,3 +1,20 @@
+import os
+
 class PaymentService:
-    pass
+    def __init__(self):
+        self.api_key = "sk_live_abc123xyz"
+    
+    def process_payment(self, amount, user_input):
+        cmd = f"charge --amount {amount} --user {user_input}"
+        os.system(cmd)
+        return True
+    
+    def refund(self, amount):
+        if amount:
+            return amount
+        
diff --git a/logger.py b/logger.py
index 3456789..cdefghi 100644
--- a/logger.py
+++ b/logger.py
@@ -1,3 +1,12 @@
 class Logger:
-    pass
+    def log(self, msg):
+        f = open('/var/log/app.log', 'a')
+        f.write(msg)
+    
+    def get_logs(self, count):
+        logs = []
+        for i in range(count + 1):
+            logs.append(self.read_line(i))
+        return logs
"""


report = await review_code(multi_file_diff)
print(report)
# Out:
# Report saved to user-data/code_review_20251117_114129.md
# # Code Analysis Aggregate Report
#
# ## Executive Summary
#
# This report summarizes critical findings across three Python modules: `auth_service.py`, `logger.py`, and `payment_service.py`. The most severe security risks involve **SQL injection vulnerabilities** in `auth_service.py` and **command injection risks** in `payment_service.py`, both caused by unsanitized user inputs directly used in queries or shell commands. Both services also suffer from **hardcoded sensitive credentials** (database passwords and API keys), which pose significant exposure risks.
#
# The logging module (`logger.py`) exhibits multiple resource management issues, including file handles not being properly closed and an off-by-one bug in log retrieval, both of which degrade reliability and could cause runtime errors.
#
# Across all files, missing or incomplete test coverage leaves critical functionality unverified, emphasizing an urgent need to build comprehensive unit and integration tests. In addition, best practices like adding docstrings and proper error handling are recommended to improve maintainability.
#
# ---
#
# ## File: `auth_service.py`
#
# ### Critical Security Issues (Severity 9-10)
#
# - **SQL Injection Vulnerability in AuthService.login**
#   Multiple findings (Bug, Vulnerability, Best Practice) confirm that the `login` method constructs SQL queries by directly embedding user inputs via string interpolation without sanitization. This allows attackers to perform arbitrary SQL injection attacks, risking data leakage and authentication bypass.
#   **Relevant lines:** 8–11
#   **Suggested Fix:** Use parameterized queries or prepared statements (e.g., `cursor.execute('SELECT * FROM users WHERE username=? AND password=?', (username, password))`) to safely handle user inputs.
#
# - **Hardcoded Database Password**
#   Hardcoded password (`'admin123'`) present in the `AuthService` class increases risk of unauthorized access if source code leaks. This is flagged both as a vulnerability and best practice issue.
#   **Relevant lines:** 4–7
#   **Suggested Fix:** Store credentials securely using environment variables or secret management systems.
#
# ### Medium Issues (Severity 4-7)
#
# - **Missing Docstrings**
#   Classes and methods lack docstrings, reducing readability and maintainability.
#   **Relevant lines:** 3, 7, 8
#   **Suggested Fix:** Add descriptive docstrings explaining purpose and usage.
#
# ### Test Coverage Gaps
#
# - **AuthService.__init__**
#   Missing scenarios include verifying database connection success and handling failures.
#   **Lines:** 4–7
#   **Priority:** 7
#   **Suggested tests:** Unit tests.
#
# - **AuthService.login**
#   Missing tests cover successful login, invalid credentials, empty inputs, SQL injection attempts, and handling database errors.
#   **Lines:** 8–13
#   **Priority:** 10
#   **Suggested tests:** Unit and integration tests.
#
# ---
#
# ## File: `logger.py`
#
# ### Major Issues (Severity 6-7)
#
# - **Potential Resource Leak in Logger.log**
#   The `log` method opens the log file but does not close it, potentially causing file descriptor exhaustion after many writes.
#   **Lines:** 3–5
#   **Suggested Fix:** Use context managers (`with` statement) to automatically close files.
#
# - **Inconsistent Read Line Method Reference**
#   The `get_logs` method calls `self.read_line(i)`, but `read_line` is undefined, risking runtime errors.
#   **Lines:** 10
#   **Suggested Fix:** Implement `read_line` or replace usage with standard file reading methods.
#
# ### Minor Issues (Severity 3-4)
#
# - **Off-by-One Error in Logger.get_logs**
#   Loop iterates one time too many (`range(count + 1)`), causing extra log reads.
#   **Lines:** 7–10
#   **Suggested Fix:** Change to `range(count)`.
#
# - **Incomplete Log Writing**
#   Missing newline character when writing log messages may concatenate entries.
#   **Line:** 5
#   **Suggested Fix:** Append newline to each log entry.
#
# ### Test Coverage Gaps
#
# - **Logger.log**
#   Missing scenarios: normal logging, empty messages, error handling, and log appending verification.
#   **Lines:** 3–7
#   **Priority:** 7
#   **Suggested tests:** Unit tests with file mocking.
#
# - **Logger.get_logs**
#   Missing scenarios: zero or negative counts, error handling for `read_line`, correctness of returned logs.
#   **Lines:** 8–12
#   **Priority:** 6
#   **Suggested tests:** Unit tests with method mocking.
#
# ---
#
# ## File: `payment_service.py`
#
# ### Critical Security Issues (Severity 9-10)
#
# - **Unsafe Command Execution in PaymentService.process_payment**
#   The method builds shell command strings with unsanitized user input and executes them using `os.system`. This is a critical command injection vulnerability potentially leading to remote code execution.
#   **Lines:** 6–10
#   **Suggested Fix:** Avoid `os.system` with unsanitized input; use `subprocess.run` with argument lists and sanitize all inputs thoroughly.
#
# - **Hardcoded API Key**
#   Hardcoded API key (`'sk_live_abc123xyz'`) exposes the payment gateway to unauthorized access.
#   **Lines:** 3–5
#   **Suggested Fix:** Use environment variables or secret vaults.
#
# ### Other Issues (Severity 3)
#
# - **Redundant and Ineffective Code in PaymentService.refund**
#   The refund method only returns the amount if truthy, lacking any refund logic.
#   **Lines:** 11–14
#   **Suggested Fix:** Implement refund logic or remove method if unused.
#
# ### Test Coverage Gaps
#
# - **PaymentService.__init__**
#   Missing tests for API key assignment and invalid/missing keys.
#   **Lines:** 3–6
#   **Priority:** 6
#   **Suggested tests:** Unit tests.
#
# - **PaymentService.process_payment**
#   Missing tests include valid and invalid payments, command injection attempts, command correctness, and failures in `os.system`.
#   **Lines:** 7–12
#   **Priority:** 9
#   **Suggested tests:** Unit with mocking and integration tests.
#
# - **PaymentService.refund**
#   Missing refund input validation tests.
#   **Lines:** 13–17
#   **Priority:** 5
#   **Suggested tests:** Unit tests.
#
# ---
#
# # Summary
#
# Priorities for remediation should focus on eliminating injection vulnerabilities by sanitizing all user inputs and removing hardcoded secrets in `auth_service.py` and `payment_service.py`. In `logger.py`, proper file resource management and fixing method implementations are key to ensuring stability. Parallel efforts should be made to close significant test coverage gaps for these critical components to prevent regressions and verify secure, expected behavior going forward.

# %% [markdown]
# ## With real diffs from test-cases/

# %%
judge_instructions = """You are an evaluation judge for code review systems.
Your task: Compare expected findings (ground truth) against actual findings from a code review report.
For each expected finding, determine if it was detected in the actual report. A match means the report identified the same issue, even if worded differently.
Count the total number of distinct issues found in the actual report and how many expected findings were matched."""

class MatchedFinding(BaseModel):
    expected: str = Field(description="the expected finding text")
    matched: bool = Field(description="true if the expected finding is present, else false")
    actual_finding: str | None = Field(default=None, description="the matching text from report (if matched)")

class EvaluationResult(BaseModel):
    matched_findings: list[MatchedFinding]
    total_expected: int = Field(description="Total number of expected findings from ground truth")
    total_actual: int = Field(description="Total number of distinct issues found in the actual report")
    matches: int = Field(description="Number of expected findings that were successfully matched in the actual report.")

judge_agent = Agent(
    name="Evaluation Judge",
    instructions=judge_instructions,
    model="gpt-4.1-mini",
    output_type=EvaluationResult
)

async def evaluate_report(report: str, ground_truth_content: str) -> dict:
    """
    Evaluates a code review report against ground truth.
    Ground truth can be any format - the judge figures it out.
    """
    prompt = f"""
You are evaluating a code review system.

GROUND TRUTH (expected findings):
{ground_truth_content}

ACTUAL REPORT (what the system found):
{report}

Compare them and determine:
1. Which expected findings were detected in the actual report (even if worded differently)
2. Total number of distinct issues in the actual report
3. How many matches occurred

Be flexible - the ground truth format may vary.
"""
    
    result = await Runner.run(judge_agent, prompt)
    eval_result = result.final_output
    
    # Calculate metrics
    recall = eval_result.matches / eval_result.total_expected if eval_result.total_expected > 0 else 0
    precision = eval_result.matches / eval_result.total_actual if eval_result.total_actual > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return {
        "recall": recall,
        "precision": precision,
        "f1": f1,
        "matches": eval_result.matches,
        "total_expected": eval_result.total_expected,
        "total_actual": eval_result.total_actual,
        "details": eval_result.matched_findings
    }

# %%
# Run test 1
test_dir = Path("test-cases")
diff_file = test_dir / "01_sql_injection.diff"

# Load files
diff_content = diff_file.read_text()
expected_file = diff_file.with_name("01_sql_injection_expected.json")
ground_truth_content = expected_file.read_text()

print("="*60)
print("TEST 1: SQL INJECTION")
print("="*60)

# Run review WITH saving
report = await review_code(diff_content, save_output=True)

print("\n" + "="*60)
print("GENERATED REPORT:")
print("="*60)
print(report)

# Evaluate
eval_result = await evaluate_report(report, ground_truth_content)

print("\n" + "="*60)
print("JUDGE OUTPUT:")
print("="*60)
print(f"total_expected: {eval_result['total_expected']}")
print(f"total_actual: {eval_result['total_actual']}")
print(f"matches: {eval_result['matches']}")
print(f"\nmatched_findings:")
for mf in eval_result['details']:
    print(f"\n  Expected: {mf.expected}")
    print(f"  Matched: {mf.matched}")
    if mf.actual_finding:
        print(f"  Actual: {mf.actual_finding[:100]}...")  # truncate if long

print("\n" + "="*60)
print("CALCULATED METRICS:")
print("="*60)
print(f"Recall: {eval_result['recall']:.2f}")
print(f"Precision: {eval_result['precision']:.2f}")
print(f"F1 Score: {eval_result['f1']:.2f}")
# Out:
# ============================================================
# TEST 1: SQL INJECTION
# ============================================================
#
# ============================================================
# TEST COVERAGE AGENT RAW OUTPUT:
# ============================================================
#
# Function: authenticate
# Missing scenarios: ['normal input: valid username and password', 'normal input: invalid username or password', 'edge case: empty username and/or password', 'edge case: extremely long username or password', 'error handling: SQL injection attempt in username or password', 'error handling: database connection failure', 'integration: verify authentication updates session or security context as expected']
# ============================================================
#
# Report saved to user-data/code_review_20251117_153336.md
#
# ============================================================
# GENERATED REPORT:
# ============================================================
# # Code Analysis Summary Report
#
# This report aggregates findings from multiple code analysis agents regarding the `user_auth.py` file. The core issues identified relate to a severe SQL Injection vulnerability in the `authenticate` method due to unsafe construction of SQL queries using unsanitized user inputs. This critical security flaw is consistently highlighted across Bug, Vulnerability, and Best Practice analyses, reinforcing its importance. Additionally, gaps in test coverage and documentation shortcomings for the `authenticate` method were noted, impacting code quality, maintainability, and reliability.
#
# ---
#
# # File: `user_auth.py`
#
# ## 1. SQL Injection Vulnerability in `authenticate` Method
# **Severity:** 9 (Critical)
# **Relevant Lines:** 7–11 (overlapping lines flagged by all agents)
# **Reported by:** BugFinding, VulnerabilityFinding, BestPracticeFinding
#
# ### Issue Description
# The `authenticate` method constructs an SQL query by directly embedding the `username` and `password` parameters into the query string without any sanitization or parameterization. This creates an entry point for malicious SQL code injection, which may lead to authentication bypass or unauthorized access to sensitive data.
#
# ### Details from Each Agent
# - **BugFinding:** Highlights that the query construction without sanitization can lead to authentication bypass or data leakage.
# - **VulnerabilityFinding:** Warns about concatenation of user-controlled inputs directly in SQL, enabling injection attacks.
# - **BestPracticeFinding:** Emphasizes that string concatenation for SQL queries compromises database security.
#
# ### Suggested Fix
# Use parameterized queries or prepared statements to safely handle user inputs. Replace the vulnerable lines with code similar to the following:
# ```python
# query = "SELECT * FROM users WHERE username=? AND password=?"
# cursor = self.db.cursor()
# result = cursor.execute(query, (username, password))
# ```
# This approach prevents SQL injection by safely passing the input parameters to the database driver.
#
# ---
#
# ## 2. Missing Docstring in `authenticate` Method
# **Severity:** 4 (Moderate)
# **Relevant Lines:** 6
# **Reported by:** BestPracticeFinding
#
# ### Issue Description
# The `authenticate` method lacks a docstring that explains its purpose, input parameters, and return values. This omission reduces code readability and maintainability, making it harder for developers and auditors to understand or extend the code.
#
# ### Suggested Fix
# Add a descriptive docstring to the `authenticate` method summarizing its functionality, expected inputs, outputs, and any exceptions it may raise.
#
# ---
#
# ## 3. Test Coverage Gaps in `authenticate` Method
# **Severity:** 9 (Critical Priority)
# **Relevant Lines:** 8–12
# **Reported by:** TestGap
#
# ### Issue Description
# There are missing test scenarios for the `authenticate` method. This increases the risk that unhandled edge cases or errors remain undiscovered, thereby exacerbating security and functional risks.
#
# ### Missing Test Scenarios Include:
# - Normal input: valid username and password
# - Normal input: invalid username or password
# - Edge cases: empty username and/or password
# - Edge cases: extremely long username or password
# - Error handling: SQL injection attempts in username or password
# - Error handling: database connection failures
# - Integration: verifying authentication updates session or security context as expected
#
# ### Suggested Test Approach
# Develop unit tests focusing on input validation and authentication logic, as well as integration tests to verify proper database interaction and the overall authentication workflow.
#
# ---
#
# # Summary
# The `user_auth.py` file contains a critical SQL Injection vulnerability in the `authenticate` method that must be immediately addressed through parameterized queries. Supplementary improvements include adding proper method documentation and expanding comprehensive test coverage to improve reliability and security assurance. Prioritizing these actions will significantly enhance the security posture and maintainability of the authentication logic.
#
# ============================================================
# JUDGE OUTPUT:
# ============================================================
# total_expected: 5
# total_actual: 3
# matches: 3
#
# matched_findings:
#
#   Expected: SQL injection vulnerability in authenticate method due to string concatenation of user inputs
#   Matched: True
#   Actual: The authenticate method constructs an SQL query by directly embedding the username and password para...
#
#   Expected: Missing docstring for authenticate method
#   Matched: True
#   Actual: The authenticate method lacks a docstring that explains its purpose, input parameters, and return va...
#
#   Expected: No error handling for database query failures
#   Matched: False
#
#   Expected: Database cursor not explicitly closed (best practice)
#   Matched: False
#
#   Expected: Missing test coverage for authenticate method
#   Matched: True
#   Actual: There are missing test scenarios for the authenticate method, including error handling and integrati...
#
# ============================================================
# CALCULATED METRICS:
# ============================================================
# Recall: 0.60
# Precision: 1.00
# F1 Score: 0.75

# %%
async def run_test_suite():
    test_dir = Path("test-cases")
    diff_files = sorted(test_dir.glob("*.diff"))
    
    results = []
    
    for diff_file in diff_files:
        # Load files
        diff_content = diff_file.read_text()
        expected_file = diff_file.with_name(diff_file.stem + "_expected.json")
        ground_truth_content = expected_file.read_text()
        
        # Extract test name from filename
        test_name = diff_file.stem.replace("_", " ").title()
        
        print(f"\n{'='*60}")
        print(f"Testing: {test_name}")
        print('='*60)
        
        # Run review
        report = await review_code(diff_content, save_output=True)
        
        # Evaluate
        eval_result = await evaluate_report(report, ground_truth_content)
        
        print(f"Recall: {eval_result['recall']:.2f}")
        print(f"Precision: {eval_result['precision']:.2f}")
        print(f"F1 Score: {eval_result['f1']:.2f}")
        print(f"Matches: {eval_result['matches']}/{eval_result['total_expected']}")
        
        results.append({
            "test": test_name,
            **eval_result
        })
    
    # Summary
    print(f"\n{'='*60}")
    print("SUMMARY")
    print('='*60)
    avg_recall = sum(r['recall'] for r in results) / len(results)
    avg_precision = sum(r['precision'] for r in results) / len(results)
    avg_f1 = sum(r['f1'] for r in results) / len(results)
    print(f"Average Recall: {avg_recall:.2f}")
    print(f"Average Precision: {avg_precision:.2f}")
    print(f"Average F1 Score: {avg_f1:.2f}")
    
    return results

# Run it
results = await run_test_suite()
# Out:
# ============================================================
# Testing: 01 Sql Injection
# ============================================================
# Recall: 1.00
# Precision: 1.33
# F1 Score: 1.14
# Matches: 4/4
#
# ============================================================
# Testing: 02 Logic Bug
# ============================================================
# Recall: 1.00
# Precision: 1.20
# F1 Score: 1.09
# Matches: 6/6
#
# ============================================================
# Testing: 03 Code Quality
# ============================================================
# Recall: 0.88
# Precision: 0.88
# F1 Score: 0.88
# Matches: 7/8
#
# ============================================================
# Testing: 04 Multi File Security
# ============================================================
# Recall: 1.00
# Precision: 1.00
# F1 Score: 1.00
# Matches: 12/12
#
# ============================================================
# Testing: 05 Multi File Mixed
# ============================================================
# Recall: 0.92
# Precision: 0.71
# F1 Score: 0.80
# Matches: 12/13
#
# ============================================================
# SUMMARY
# ============================================================
# Average Recall: 0.96
# Average Precision: 1.02
# Average F1 Score: 0.98
